# %%
# https://www.wunderground.com/history/monthly/gb/london/EGLC
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
# 특정 작업이 실행될떄까지 기다린다
from selenium.webdriver.support import expected_conditions as EC
# EC.presence_of_element_located((By.ID, "myDynamicElement"))
from selenium.webdriver.common.by import By
import time

# %%
# 크롬드라이버 실행
browser = webdriver.Chrome('C:/Users/tongy/Programming/BigDataUI/Python/jupyter/chromedriver.exe')

# %%
# 파일이 끝까지 로딩될때까지 최대 10초를 대기한다
browser.implicitly_wait(10)

# %%
# 지정된 url로 접근한다
browser.get('https://www.wunderground.com/history/monthly/gb/london/EGLC')

# %%
# 현재 페이지의 내용을 확인해본다
print('현재 페이지 내용:{}' .format(browser.page_source))
# Out:
# 현재 페이지 내용:<html lang="en" itemscope="" itemtype="http://schema.org/Organization" prefix="og: http://ogp.me/ns#"><head itemscope="" itemtype="http://schema.org/WebSite">
#   <meta charset="utf-8">
#   <title>London, United Kingdom Weather History | Weather Underground</title>
#   <base href="/">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#   <link rel="dns-prefetch" href="//widgets.outbrain.com">
#   <link rel="dns-prefetch" href="//odb.outbrain.com">
#   <link rel="dns-prefetch" href="//c.amazon-adsystem.com">
#   <link rel="dns-prefetch" href="//s.amazon-adsystem.com">
#   <link rel="dns-prefetch" href="//aax.amazon-adsystem.com">
#   <link rel="dns-prefetch" href="//partner.googleadservices.com">
#   <link rel="dns-prefetch" href="//tpc.googlesyndication.com">
#   <link rel="dns-prefetch" href="//pagead2.googlesyndication.com">
#   <link rel="dns-prefetch" href="//h.nexac.com">
# ...

# %%
# 검색창 선택
month = browser.find_element_by_css_selector('#monthSelection')
year = browser.find_element_by_css_selector('#yearSelection')

# %%
# 월 입력
month.send_keys('February')

# %%
# 년도 입력
year.send_keys('2020')

# %%
# 검색(submit)
search = browser.find_element_by_css_selector('#dateSubmit')

# %%
search.click()

# %%
# bs4 임포트
from bs4 import BeautifulSoup

# %%
# html을 긁어와서 soup에 저장
soup = BeautifulSoup(browser.page_source, 'html.parser')

# %%
# 온도정보를 저장
temp_list=soup.select('#inner-content > div.region-content-main > div.row > div:nth-child(5) > div:nth-child(1) > div > lib-city-history-observation > div > div.observation-table.ng-star-inserted > table > tbody > tr > td:nth-child(2) > table > tr > td:nth-child(2)')
#temp_list

# %%
# 날짜정보를 저장
day_list=soup.select('#inner-content > div.region-content-main > div.row > div:nth-child(5) > div:nth-child(1) > div > lib-city-history-observation > div > div.observation-table.ng-star-inserted > table > tbody > tr > td:nth-child(1) > table > tr > td')

# %%
# 풍속정보
wind_list = soup.select('#inner-content > div.region-content-main > div.row > div:nth-child(5) > div:nth-child(1) > div > lib-city-history-observation > div > div.observation-table.ng-star-inserted > table > tbody > tr > td:nth-child(5) > table > tr > td:nth-child(2)')

# %%
len(day_list)
day_list
# Out:
# [<td _ngcontent-app-root-c206="" class="ng-star-inserted"> Feb </td>,
#  <td _ngcontent-app-root-c206="" class="ng-star-inserted"> 1 </td>,
#  <td _ngcontent-app-root-c206="" class="ng-star-inserted"> 2 </td>,
#  <td _ngcontent-app-root-c206="" class="ng-star-inserted"> 3 </td>,
#  <td _ngcontent-app-root-c206="" class="ng-star-inserted"> 4 </td>,
#  <td _ngcontent-app-root-c206="" class="ng-star-inserted"> 5 </td>,
#  <td _ngcontent-app-root-c206="" class="ng-star-inserted"> 6 </td>,
#  <td _ngcontent-app-root-c206="" class="ng-star-inserted"> 7 </td>,
#  <td _ngcontent-app-root-c206="" class="ng-star-inserted"> 8 </td>,
#  <td _ngcontent-app-root-c206="" class="ng-star-inserted"> 9 </td>,
#  <td _ngcontent-app-root-c206="" class="ng-star-inserted"> 10 </td>,
#  <td _ngcontent-app-root-c206="" class="ng-star-inserted"> 11 </td>,
#  <td _ngcontent-app-root-c206="" class="ng-star-inserted"> 12 </td>,
#  <td _ngcontent-app-root-c206="" class="ng-star-inserted"> 13 </td>,
# ...

# %%
len(temp_list)
# Out:
# 31

# %%
len(wind_list)
# Out:
# 31
